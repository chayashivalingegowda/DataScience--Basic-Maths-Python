# %%
import pandas as pd
df=pd.read_csv('/home/aiktc/Downloads/weather.csv')

# %%
df.shape
# Out:
# (14, 5)

# %%
df=pd.dataframe(df,columns=['temperature','humidity','windy'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-85add4a3624f> in <module>
# ----> 1 df=pd.dataframe(df,columns=['temperature','humidity','windy'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
df.head
# Out:
# <bound method NDFrame.head of      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes>

# %%
df[2:5]
# Out:
#     outlook temperature humidity  windy play
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes

# %%
df[0:5]
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes

# %%
df.columns
# Out:
# Index(['outlook', 'temperature', 'humidity', 'windy', 'play'], dtype='object')

# %%
df.windy
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# Name: windy, dtype: bool

# %%
df['windy']
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# Name: windy, dtype: bool

# %%
df['windy'].max()
# Out:
# True

# %%
df[df.windy==df.windy.max()]
# Out:
#      outlook temperature humidity  windy play
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 6      rainy        cool   normal   True   no
# 8      rainy        mild     high   True   no
# 10     sunny         hot     high   True   no
# 13     sunny        mild   normal   True  yes

# %%
df.windy[df.temperature==df.temperature.max()]
# Out:
# 2      True
# 4     False
# 7     False
# 8      True
# 11    False
# 13     True
# Name: windy, dtype: bool

# %%
g=df.groupby('windy')

# %%
for windy,windy_g in g:
    print(windy)
    print(windy_g)
# Out:
# False
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 7      rainy        mild   normal  False  yes
# 9      sunny         hot     high  False   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# True
#      outlook temperature humidity  windy play
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 6      rainy        cool   normal   True   no
# 8      rainy        mild     high   True   no
# 10     sunny         hot     high   True   no
# 13     sunny        mild   normal   True  yes

# %%
print(g.mean())
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-27-355203eee933> in <module>
# ----> 1 print(g.mean())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
# ...

# %%
print(g.describe())
# Out:
#       outlook                    temperature                   humidity  \
#         count unique    top freq       count unique   top freq    count
# windy
# False       8      3  sunny    3           8      3   hot    3        8
# True        6      3  sunny    2           6      3  mild    3        6
#
#                          play
#       unique   top freq count unique  top freq
# windy
# False      2  high    4     8      2  yes    6
# True       2  high    3     6      2   no    3

# %%
df = pd.DataFrame([1,2,3,4],index=[20,21,1,2])

# %%
df
# Out:
#     0
# 20  1
# 21  2
# 1   3
# 2   4

# %%
df.loc[21]
# Out:
# 0    2
# Name: 21, dtype: int64

# %%
df.iloc[:2]
# Out:
#     0
# 20  1
# 21  2

# %%
#space and complexity

# %%
import numpy as np
li = np.arange(1000000);
import time

start_time = time.time();

flag=False;
for ele in li:
    if(ele==19999000):
        print("found");
        flag=True
        break;
if(flag==False):
    print("NotFound");
end_time = time.time();

print("Time Taken: ",end_time - start_time);
# Out:
# NotFound
# Time Taken:  0.4746222496032715

# %%
ele
# Out:
# 999999

# %%
import seaborn as sns
from sklearn import datasets

#loading dataset
iris = datasets.load_iris()
df.head()
sns.set_style('whitegrid')
sns.pairplot(iris,hue="Species",size=3,diag_kind="kde")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-3196423c8c16> in <module>
#       6 df.head()
#       7 sns.set_style('whitegrid')
# ----> 8 sns.pairplot(iris,hue="Species",size=3,diag_kind="kde")
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2068         raise TypeError(
#    2069             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2070                 typefound=type(data)))
#    2071
#    2072     if plot_kws is None:
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'sklearn.utils.Bunch'>

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/home/aiktc/Downloads/iris/Iris.csv')

sns.set_style('whitegrid')
sns.pairplot(df,hue="Species",size=3)
plt.show()
